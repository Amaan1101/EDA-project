# %%
#this is the dataset about the performance of the players in ipl match
#THE DATASET IS ABOUT THE IPL MATCH.
#IT SHOWS THE NAME OF THE PLAYERS, THE POSITION OF THE PLAYERS, NUMBER OF MATCHES PLAYED(Mat), NUMBER OF INNINGS PLAYED(Inns),
#THE NUMBERS OF NOT OUTS(NO), NUMBER OF RUNS SCORED BY THE PARTICULAR PLAYER(Runs), THE HEIGH SCORE OF THE PLAYER(HS),
#THE AVERAGE SCORE OF THE PLAYER(Avg), THE BALL FACED BY THE PLAYERS(BF), THE STRIKE RATE OF THE PLAYER(SR),
#THE NUMBER OF CENTURIES(100), THE NUMBERS OF HALF CENTURIES(50) AND THE NUMBER OF FOURS AND SIXES SCORED.

# %%
#Importing necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf

# %%
df=pd.read_csv(r"ipl_Data.csv") #dataset

# %%
df
# Out:
#     Unnamed: 0  POS            PLAYER  Mat  Inns  NO  Runs   HS    Avg   BF  \
# 0            0    1   Shikhar  Dhawan    8     8   1   380   92  54.28  283
# 1            1    2         KL  Rahul    7     7   2   331  91*  66.20  243
# 2            2    3   Faf  du Plessis    7     7   2   320  95*  64.00  220
# 3            3    4     Prithvi  Shaw    8     8   0   308   82  38.50  185
# 4            4    5     Sanju  Samson    7     7   1   277  119  46.16  190
# ..         ...  ...               ...  ...   ...  ..   ...  ...    ...  ...
# 95          95   96  Harbhajan  Singh    3     2   2     4   2*      -    4
# 96          96   97   Jasprit  Bumrah    7     3   2     4   3*   4.00    6
# 97          97   98    Dan  Christian    3     3   0     3    1   1.00    8
# 98          98   99    Navdeep  Saini    1     1   0     2    2   2.00    4
# 99          99  100   Arshdeep  Singh    6     2   2     2   1*      -    3
#
#         SR  100  50  4s  6s
# ...

# %%
#First 5 entries of the data set

df.head()
# Out:
#    Unnamed: 0  POS           PLAYER  Mat  Inns  NO  Runs   HS    Avg   BF  \
# 0           0    1  Shikhar  Dhawan    8     8   1   380   92  54.28  283
# 1           1    2        KL  Rahul    7     7   2   331  91*  66.20  243
# 2           2    3  Faf  du Plessis    7     7   2   320  95*  64.00  220
# 3           3    4    Prithvi  Shaw    8     8   0   308   82  38.50  185
# 4           4    5    Sanju  Samson    7     7   1   277  119  46.16  190
#
#        SR  100  50  4s  6s
# 0  134.27    0   3  43   8
# 1  136.21    0   4  27  16
# 2  145.45    0   4  29  13
# 3  166.48    0   3  37  12
# 4  145.78    1   0  26  11

# %%
#Last 5 entries of the dataset

df.tail()
# Out:
#     Unnamed: 0  POS            PLAYER  Mat  Inns  NO  Runs  HS   Avg  BF  \
# 95          95   96  Harbhajan  Singh    3     2   2     4  2*     -   4
# 96          96   97   Jasprit  Bumrah    7     3   2     4  3*  4.00   6
# 97          97   98    Dan  Christian    3     3   0     3   1  1.00   8
# 98          98   99    Navdeep  Saini    1     1   0     2   2  2.00   4
# 99          99  100   Arshdeep  Singh    6     2   2     2  1*     -   3
#
#         SR  100  50  4s  6s
# 95  100.00    0   0   0   0
# 96   66.66    0   0   0   0
# 97   37.50    0   0   0   0
# 98   50.00    0   0   0   0
# 99   66.66    0   0   0   0

# %%
#The information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   POS         100 non-null    int64
#  2   PLAYER      100 non-null    object
#  3   Mat         100 non-null    int64
#  4   Inns        100 non-null    int64
#  5   NO          100 non-null    int64
#  6   Runs        100 non-null    int64
#  7   HS          100 non-null    object
#  8   Avg         100 non-null    object
#  9   BF          100 non-null    int64
#  10  SR          100 non-null    float64
#  11  100         100 non-null    int64
#  12  50          100 non-null    int64
#  13  4s          100 non-null    int64
#  14  6s          100 non-null    int64
# dtypes: float64(1), int64(11), object(3)
# memory usage: 11.8+ KB

# %%
#Displaying max rows and columns of the dataset

pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#     Unnamed: 0  POS                PLAYER  Mat  Inns  NO  Runs    HS     Avg  \
# 0            0    1       Shikhar  Dhawan    8     8   1   380    92   54.28
# 1            1    2             KL  Rahul    7     7   2   331   91*   66.20
# 2            2    3       Faf  du Plessis    7     7   2   320   95*   64.00
# 3            3    4         Prithvi  Shaw    8     8   0   308    82   38.50
# 4            4    5         Sanju  Samson    7     7   1   277   119   46.16
# 5            5    6       Mayank  Agarwal    7     7   1   260   99*   43.33
# 6            6    7          Jos  Buttler    7     7   0   254   124   36.28
# 7            7    8         Rohit  Sharma    7     7   0   250    63   35.71
# 8            8    9       Jonny  Bairstow    7     7   1   248   63*   41.33
# 9            9   10        Glenn  Maxwell    7     6   0   223    78   37.16
# 10          10   11         Rishabh  Pant    8     8   2   213   58*   35.50
# ...

# %%
#Subplot of RUNS, MAT, INNS AND AVERAGE.
cat_cols = ['Runs', 'Mat','Inns','Avg']
i=0
while i < 4:
    fig = plt.figure(figsize=[20,5])
    
    
    
    plt.subplot(1,2,1)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1
    
    
    plt.subplot(1,2,2)
    sns.countplot(x=cat_cols[i], data=df)
    i += 1
    
    plt.show()

# %%
#The pairplot of the data.
sns.pairplot(df)

# %%
#Boxplot of the number of runs, mat, innings and half centuries.

num_cols = ['Runs', 'Mat','Inns','50']
i=0
while i < 4:
    fig = plt.figure(figsize=[13,3])
    
    
    plt.subplot(1,2,1)
    sns.boxplot(x=num_cols[i], data=df)
    i += 1
    

    plt.subplot(1,2,2)
    sns.boxplot(x=num_cols[i], data=df)
    i += 1
    
    plt.show()

# %%
#Sorting the values of players names.

df.sort_values(by="PLAYER")
# Out:
#     Unnamed: 0  POS                PLAYER  Mat  Inns  NO  Runs    HS     Avg  \
# 11          11   12       AB  de Villiers    7     6   2   207   76*   51.75
# 57          57   58          Abdul  Samad    4     4   1    36   19*   12.00
# 89          89   90      Abhishek  Sharma    3     2   0     7     5    3.50
# 85          85   86       Ajinkya  Rahane    2     1   0     8     8    8.00
# 26          26   27        Ambati  Rayudu    7     5   1   136   72*   34.00
# 23          23   24        Andre  Russell    7     7   1   163    54   27.16
# 99          99  100       Arshdeep  Singh    6     2   2     2    1*       -
# 71          71   72    Bhuvneshwar  Kumar    5     3   2    17   14*   17.00
# 20          20   21          Chris  Gayle    8     8   1   178    46   25.42
# 60          60   61         Chris  Jordan    3     2   0    32    30   16.00
# 51          51   52           Chris  Lynn    1     1   0    49    49   49.00
# ...

# %%
#Sorting the values of players in descending order.

df["PLAYER"].value_counts().sort_values(ascending=False)
# Out:
# Harshal  Patel          1
# Shivam  Dube            1
# Chris  Lynn             1
# Faf  du Plessis         1
# Jayant  Yadav           1
# Manish  Pandey          1
# Dawid  Malan            1
# Ajinkya  Rahane         1
# David  Miller           1
# Wriddhiman  Saha        1
# Ishan  Kishan           1
# Sunil  Narine           1
# Chris  Gayle            1
# Ravindra  Jadeja        1
# Jason  Holder           1
# Daniel  Sams            1
# Chris  Morris           1
# Rahul  Tewatia          1
# Kane  Williamson        1
# Mohammad  Nabi          1
# Washington  Sundar      1
# Mohammed  Siraj         1
# Arshdeep  Singh         1
# Bhuvneshwar  Kumar      1
# Rajat  Patidar          1
# Rashid  Khan            1
# Virat  Kohli            1
# Chris  Jordan           1
# Suryakumar  Yadav       1
# Manan  Vohra            1
# Jagadeesha  Suchith     1
# Harpreet  Brar          1
# Moeen  Ali              1
# AB  de Villiers         1
# Nitish  Rana            1
# ...

# %%
#Heatmap.

sns.heatmap(df.corr(), annot=True, cmap="RdBu")
plt.show()
